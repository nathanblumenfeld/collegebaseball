# %%
import ncaa_scrape as ncaa
import pandas as pd
import metrics

# %%
metrics.add_pitching_metrics(ncaa.get_career_stats(2111716, 'pitching'))
# Out:
#   school_id  GP   G  App  GS    ERA    IP   CG   H   R  ... OBP-against  \
# 0       167  11  11   11   0   4.50  12.0  0.0  15   6  ...       0.404
# 1       167   3   3    3   0   7.94   5.2  0.0   7   6  ...       0.385
# 2       167   3   3    3   2  20.57   7.0  0.0  13  17  ...       0.574
#
#    BA-against  SLG-against  OPS-against   K/PA     K/9  BB/PA   BB/9  \
# 0       0.333        0.400        0.804  0.135   5.250  0.115  1.038
# 1       0.304        0.522        0.907  0.308  12.706  0.115  1.038
# 2       0.394        0.758        1.332  0.064   3.857  0.191  1.723
#
#   BABIP-against     FIP
# 0         0.326   4.174
# 1         0.353   5.105
# 2         0.244  14.195
#
# [3 rows x 47 columns]

# %%
ncaa.get_career_stats(2111716, 'pitching')
# Out:
#   school_id  GP   G  App  GS    ERA    IP   CG   H   R  ... SHA  SFA  Pitches  \
# 0       167  11  11   11   0   4.50  12.0  0.0  15   6  ...   0    1      171
# 1       167   3   3    3   0   7.94   5.2  0.0   7   6  ...   0    0       69
# 2       167   3   3    3   2  20.57   7.0  0.0  13  17  ...   2    0      175
#
#    GO  FO    W    L   SV   KL  season
# 0  11  13  0.0  0.0  0.0    4    2018
# 1   3   5  0.0  0.0  0.0    3    2019
# 2   9   7  0.0    2  0.0  0.0    2021
#
# [3 rows x 35 columns]

# %%
ncaa.lookup_seasons_played(2111724)
# Out:
# (2019, 2021)

# %%
metrics.add_pitching_metrics(ncaa.get_team_stats("cornell", 2019, "pitching"))
# Out:
#     Jersey                 name  Yr pos  GP  GS  App  GS   ERA    IP  ...  \
# 10      34          John Natoli  Jr   P  19   1   19   1  1.73  36.1  ...
# 11       1      Nikolas Lillios  Fr   P  15   5    9   0  3.27  11.0  ...
# 13      32        Jon Zacharias  Fr   P  13   8   13   8  2.83  41.1  ...
# 18       8        Kevin Cushing  Fr   P  11   0   11   0  4.50  12.0  ...
# 15      31          Colby Wyatt  Jr   P  13  10   13  10  3.68  63.2  ...
# 22      20           Seth Urbon  Jr   P   7   7    7   7  8.10  33.1  ...
# 17      22           Jeb Bemiss  Jr   P  12   6   12   6  5.83  46.1  ...
# 19      40       Andrew Ellison  Jr   P  11   2   11   2  2.39  26.1  ...
# 12      26  Trevor Daniel Davis  So   P  14   0   14   0  4.96  16.1  ...
# 14      12        Luke Yacinich  Fr   P  13   4   13   4  8.07  32.1  ...
# 20      16        Austin Arnold  Sr   P   8   0    8   0  3.18   5.2  ...
# 25      27      William Gilbert  Fr   P   2   0    2   0  5.40   1.2  ...
#
# ...

# %%
ncaa.get_career_stats(2111724, 'pitching').iloc[0].IP
# Out:
# 32.1

# %%
metrics.calculate_fip(ncaa.get_career_stats(2111724, 'pitching').iloc[0])
# Out:
# 6.084

# %%
ncaa.lookup_player_id("Jake Gelof", "Virginia")
# Out:
# 2486499

# %%
ncaa.get_career_stats(1884390, 'pitching')
# Out:
#   school_id  GP  G  App  GS   ERA    IP   CG   H   R  ... SHA  SFA  Pitches  \
# 0       167  13  0   13   0  4.76  22.2  0.0  29  14  ...   2    2      291
# 1       167  15  0   15   2  6.16  30.2  0.0  39  26  ...   0    0      253
# 2       167  12  0   12   6  5.83  46.1    1  55  32  ...   2    0      376
#
#    GO  FO  W  L   SV  KL  season
# 0  19  33  1  2    1   6    2016
# 1  33  29  2  2    1  10    2017
# 2  50  46  2  3  0.0   9    2018
#
# [3 rows x 35 columns]

# %%
ncaa.get_roster('cornell', 2018)
# Out:
#    jersey stats_player_seq               name position class_year  \
# 0      25          1997329     Apostle, Jason       OF         Fr
# 1       6          1779078        Arndt, Josh      INF         Jr
# 2      16          1779080     Arnold, Austin        P         Jr
# 3      29          1997331    Bailey, Garrett        P         Fr
# 4      35          1652419         Baur, Trey      INF         Sr
# 5      22          1884390        Bemiss, Jeb        P         So
# 6       8          1997325   Binnie, Nicholas        P         Fr
# 7       2          1652397       Bitar, Ellis        C         Sr
# 8       3          1884385     Carnegie, Alex      INF         So
# 9      37          1884387      Cintron, Nick        P         So
# 10     15          1884388      Collins, Matt      INF         So
# 11     26          1997345      Davis, Trevor        P         Fr
# 12     40          1997332    Ellison, Andrew        P         So
# ...
